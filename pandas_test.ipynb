# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
pd.read_excel('C:/Users/USER/test/4G Database TWAMP_Shajahan.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-5279efbfe17e> in <module>
# ----> 1 pd.read_excel('C:/Users/USER/test/4G Database TWAMP_Shajahan.xlsx')
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
# ...

# %%
df = pd.read_excel('C:/Users/USER/test/4G Database TWAMP_Shajahan.xlsx', header=1) # read file with row 1 as header

# %%
df.head()
# Out:
#    NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID  STATE SALES REGION  \
# 0   1   CENTRAL  Ericsson      A00001  A00001_Macro  PERAK     NORTHERN
# 1   7  NORTHERN    Huawei      A00003  A00003_Macro  PERAK     NORTHERN
# 2  16  NORTHERN    Huawei      A00004  A00004_Macro  PERAK     NORTHERN
# 3  24  NORTHERN    Huawei      A00005  A00005_Macro  PERAK     NORTHERN
# 4  29  NORTHERN    Huawei      A00006  A00006_Macro  PERAK     NORTHERN
#
#   TERRITORY CODE         SALES TERRITORY SALES TIER NC_CODE  \
# 0          A037B   HILIR PERAK_BGN DATOH     Tier 2  A037B2
# 1          A045A               ULU PERAK     Tier 2  A045A3
# 2          A045A               ULU PERAK     Tier 2  A045A1
# 3          A045A               ULU PERAK     Tier 2  A045A3
# 4          A036B  BATANG PADANG_TG MALIM     Tier 2  A036B4
#
#                               NC_NAME PROJECT SITE ID  \
# 0              A037B2_HUTAN MELINTANG         CL50630
# 1                        A045A3_GERIK         NL40212
# ...

# %%
df.columns.ravel()
# Out:
# <ipython-input-16-ecc81c4c9598>:1: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   df.columns.ravel()
# array(['NO', 'REGION', 'VENDOR', 'LOCATION ID', 'ZOOM SITE ID', 'STATE',
#        'SALES REGION', 'TERRITORY CODE', 'SALES TERRITORY', 'SALES TIER',
#        'NC_CODE', 'NC_NAME', 'PROJECT SITE ID', 'SITENAME', 'LONGITUDE',
#        'LATITUDE', 'eNodeB_ID'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9385 entries, 0 to 9384
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NO               9385 non-null   int64
#  1   REGION           9385 non-null   object
#  2   VENDOR           9385 non-null   object
#  3   LOCATION ID      9385 non-null   object
#  4   ZOOM SITE ID     9385 non-null   object
#  5   STATE            9385 non-null   object
#  6   SALES REGION     9385 non-null   object
#  7   TERRITORY CODE   9385 non-null   object
#  8   SALES TERRITORY  9385 non-null   object
#  9   SALES TIER       9385 non-null   object
#  10  NC_CODE          9385 non-null   object
#  11  NC_NAME          9385 non-null   object
#  12  PROJECT SITE ID  9385 non-null   object
#  13  SITENAME         9385 non-null   object
#  14  LONGITUDE        9385 non-null   float64
#  15  LATITUDE         9385 non-null   float64
# ...

# %%
df.describe()
# Out:
#                  NO    LONGITUDE     LATITUDE      eNodeB_ID
# count   9385.000000  9385.000000  9385.000000    9385.000000
# mean   29029.471497   104.499196     3.719213  329582.175386
# std    16086.703175     5.173169     1.508547  160206.138818
# min        1.000000    99.670165     0.930750  110271.000000
# 25%    15873.000000   101.581900     2.724090  181176.000000
# 50%    29158.000000   102.223820     3.220300  321770.000000
# 75%    43316.000000   103.742469     5.213900  441656.000000
# max    56376.000000   119.206040     7.291111  660051.000000

# %%
df.loc[df['LOCATION ID'] == 'A00005']
# Out:
#    NO    REGION  VENDOR LOCATION ID  ZOOM SITE ID  STATE SALES REGION  \
# 3  24  NORTHERN  Huawei      A00005  A00005_Macro  PERAK     NORTHERN
#
#   TERRITORY CODE SALES TERRITORY SALES TIER NC_CODE       NC_NAME  \
# 3          A045A       ULU PERAK     Tier 2  A045A3  A045A3_GERIK
#
#   PROJECT SITE ID                    SITENAME   LONGITUDE  LATITUDE  eNodeB_ID
# 3         NL40216  A045A_A00005OD_FELDABERSIA  101.206581  5.470643     341216

# %%
df.iloc[1,1]
# Out:
# 'NORTHERN'

# %%
df.loc[1]
# Out:
# NO                                     7
# REGION                          NORTHERN
# VENDOR                            Huawei
# LOCATION ID                       A00003
# ZOOM SITE ID                A00003_Macro
# STATE                              PERAK
# SALES REGION                    NORTHERN
# TERRITORY CODE                     A045A
# SALES TERRITORY                ULU PERAK
# SALES TIER                        Tier 2
# NC_CODE                           A045A3
# NC_NAME                     A045A3_GERIK
# PROJECT SITE ID                  NL40212
# SITENAME           A045A_A00003OD_TMGRIK
# LONGITUDE                     101.128162
# LATITUDE                        5.431587
# eNodeB_ID                         341212
# Name: 1, dtype: object

# %% [markdown]
# # to locate the rows containing A00005 and display column LONG & LAT

# %%
df.loc[df['LOCATION ID'] == 'A00005', ['LONGITUDE','LATITUDE']]
# Out:
#     LONGITUDE  LATITUDE
# 3  101.206581  5.470643

# %%
df.head()
# Out:
#    NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID  STATE SALES REGION  \
# 0   1   CENTRAL  Ericsson      A00001  A00001_Macro  PERAK     NORTHERN
# 1   7  NORTHERN    Huawei      A00003  A00003_Macro  PERAK     NORTHERN
# 2  16  NORTHERN    Huawei      A00004  A00004_Macro  PERAK     NORTHERN
# 3  24  NORTHERN    Huawei      A00005  A00005_Macro  PERAK     NORTHERN
# 4  29  NORTHERN    Huawei      A00006  A00006_Macro  PERAK     NORTHERN
#
#   TERRITORY CODE         SALES TERRITORY SALES TIER NC_CODE  \
# 0          A037B   HILIR PERAK_BGN DATOH     Tier 2  A037B2
# 1          A045A               ULU PERAK     Tier 2  A045A3
# 2          A045A               ULU PERAK     Tier 2  A045A1
# 3          A045A               ULU PERAK     Tier 2  A045A3
# 4          A036B  BATANG PADANG_TG MALIM     Tier 2  A036B4
#
#                               NC_NAME PROJECT SITE ID  \
# 0              A037B2_HUTAN MELINTANG         CL50630
# 1                        A045A3_GERIK         NL40212
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9385, step=1)

# %%
df.columns
# Out:
# Index(['NO', 'REGION', 'VENDOR', 'LOCATION ID', 'ZOOM SITE ID', 'STATE',
#        'SALES REGION', 'TERRITORY CODE', 'SALES TERRITORY', 'SALES TIER',
#        'NC_CODE', 'NC_NAME', 'PROJECT SITE ID', 'SITENAME', 'LONGITUDE',
#        'LATITUDE', 'eNodeB_ID'],
#       dtype='object')

# %%
df['LOCATION ID']
# Out:
# 0       A00001
# 1       A00003
# 2       A00004
# 3       A00005
# 4       A00006
#          ...
# 9380    Y00023
# 9381    Y00029
# 9382    Y00048
# 9383    Y00054
# 9384    Y00056
# Name: LOCATION ID, Length: 9385, dtype: object

# %%
df.assign(tag1="Tag1:"+df['LOCATION ID'], tag2="Tag2:"+df['NC_CODE']+df['VENDOR'])
# Out:
#          NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID            STATE  \
# 0         1   CENTRAL  Ericsson      A00001  A00001_Macro            PERAK
# 1         7  NORTHERN    Huawei      A00003  A00003_Macro            PERAK
# 2        16  NORTHERN    Huawei      A00004  A00004_Macro            PERAK
# 3        24  NORTHERN    Huawei      A00005  A00005_Macro            PERAK
# 4        29  NORTHERN    Huawei      A00006  A00006_Macro            PERAK
# ...     ...       ...       ...         ...           ...              ...
# 9380  56358  SOUTHERN    Huawei      Y00023  Y00023_Macro  NEGERI SEMBILAN
# 9381  56364  NORTHERN    Huawei      Y00029  Y00029_Macro            PERAK
# 9382  56367  NORTHERN    Huawei      Y00048  Y00048_Macro            PERAK
# 9383  56370  NORTHERN    Huawei      Y00054  Y00054_Macro            KEDAH
# 9384  56376   CENTRAL    Huawei      Y00056  Y00056_Macro         SELANGOR
#
# ...

# %%
df
# Out:
#          NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID            STATE  \
# 0         1   CENTRAL  Ericsson      A00001  A00001_Macro            PERAK
# 1         7  NORTHERN    Huawei      A00003  A00003_Macro            PERAK
# 2        16  NORTHERN    Huawei      A00004  A00004_Macro            PERAK
# 3        24  NORTHERN    Huawei      A00005  A00005_Macro            PERAK
# 4        29  NORTHERN    Huawei      A00006  A00006_Macro            PERAK
# ...     ...       ...       ...         ...           ...              ...
# 9380  56358  SOUTHERN    Huawei      Y00023  Y00023_Macro  NEGERI SEMBILAN
# 9381  56364  NORTHERN    Huawei      Y00029  Y00029_Macro            PERAK
# 9382  56367  NORTHERN    Huawei      Y00048  Y00048_Macro            PERAK
# 9383  56370  NORTHERN    Huawei      Y00054  Y00054_Macro            KEDAH
# 9384  56376   CENTRAL    Huawei      Y00056  Y00056_Macro         SELANGOR
#
# ...

# %% [markdown]
# # test

# %%
df2 = pd.read_excel('C:/Users/USER/test/FNI Test Targets v3 MHS Central RAN per Port.xlsx', header=0) # read file with row 1 as header

# %%
df2
# Out:
#           IP address                         SITENAME Unnamed: 2  Latitude  \
# 0     10.226.245.145           B061O_B00009OD_KAYUARA         OK  3.128900
# 1      10.226.242.16  W067A_B00010OD_PR_PRESINT11WPPJ         OK  2.972090
# 2     10.226.245.105       B061M_B00011OD_TROPICANAGC         OK  3.130338
# 3     10.226.245.107        B061H_B00012OD_TMNDESARIA        NaN  3.081870
# 4     10.231.162.239         B061D_B00015OD_SEK20SHLM        NaN  3.054000
# ...              ...                              ...        ...       ...
# 2067             NaN                              NaN        NaN       NaN
# 2068             NaN                              NaN        NaN       NaN
# 2069             NaN                              NaN        NaN       NaN
# 2070             NaN                              NaN        NaN       NaN
# 2071             NaN                              NaN        NaN       NaN
#
# ...

# %%
df2.info
# Out:
# <bound method DataFrame.info of           IP address                         SITENAME Unnamed: 2  Latitude  \
# 0     10.226.245.145           B061O_B00009OD_KAYUARA         OK  3.128900
# 1      10.226.242.16  W067A_B00010OD_PR_PRESINT11WPPJ         OK  2.972090
# 2     10.226.245.105       B061M_B00011OD_TROPICANAGC         OK  3.130338
# 3     10.226.245.107        B061H_B00012OD_TMNDESARIA        NaN  3.081870
# 4     10.231.162.239         B061D_B00015OD_SEK20SHLM        NaN  3.054000
# ...              ...                              ...        ...       ...
# 2067             NaN                              NaN        NaN       NaN
# 2068             NaN                              NaN        NaN       NaN
# 2069             NaN                              NaN        NaN       NaN
# 2070             NaN                              NaN        NaN       NaN
# 2071             NaN                              NaN        NaN       NaN
#
# ...

# %%
df2.assign(temp=df['SITENAME'].rsplit("_"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-5e0d3f252d23> in <module>
# ----> 1 df2.assign(temp=df['SITENAME'].rsplit("_"))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'rsplit'

# %%
df[['F','S']] = df.NC_NAME.str.split("_",1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-bbf23baea534> in <module>
# ----> 1 df[['F','S']] = df.NC_NAME.str.split("_",1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3158             self._setitem_frame(key, value)
#    3159         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3160             self._setitem_array(key, value)
#    3161         else:
#    3162             # set column
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3196                 )[1]
#    3197                 self._check_setitem_copy()
# -> 3198                 self.iloc[:, indexer] = value
#    3199
#    3200     def _setitem_frame(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
# ...

# %%
df.NC_NAME.str.split("_",1)
# Out:
# 0                   [A037B2, HUTAN MELINTANG]
# 1                             [A045A3, GERIK]
# 2                    [A045A1, PENGKALAN HULU]
# 3                             [A045A3, GERIK]
# 4       [A036B4, HULU BERNAM TIMUR DAN BARAT]
#                         ...
# 9380                        [N071A3, KUNDANG]
# 9381                  [A037B1, CHANGKAT JONG]
# 9382    [A036B3, HULU BERNAM TIMUR DAN BARAT]
# 9383                          [K004A5, TAJAR]
# 9384                   [B061F3, SUNGAI BULOH]
# Name: NC_NAME, Length: 9385, dtype: object

# %%
type(df.NC_NAME.str.rsplit("_"))
# Out:
# pandas.core.series.Series

# %%
df[['test']] = "TEST"

# %%
df
# Out:
#          NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID            STATE  \
# 0         1   CENTRAL  Ericsson      A00001  A00001_Macro            PERAK
# 1         7  NORTHERN    Huawei      A00003  A00003_Macro            PERAK
# 2        16  NORTHERN    Huawei      A00004  A00004_Macro            PERAK
# 3        24  NORTHERN    Huawei      A00005  A00005_Macro            PERAK
# 4        29  NORTHERN    Huawei      A00006  A00006_Macro            PERAK
# ...     ...       ...       ...         ...           ...              ...
# 9380  56358  SOUTHERN    Huawei      Y00023  Y00023_Macro  NEGERI SEMBILAN
# 9381  56364  NORTHERN    Huawei      Y00029  Y00029_Macro            PERAK
# 9382  56367  NORTHERN    Huawei      Y00048  Y00048_Macro            PERAK
# 9383  56370  NORTHERN    Huawei      Y00054  Y00054_Macro            KEDAH
# 9384  56376   CENTRAL    Huawei      Y00056  Y00056_Macro         SELANGOR
#
# ...

# %%
df[['test1','test2']] = ['aa','bb']

# %%
df
# Out:
#          NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID            STATE  \
# 0         1   CENTRAL  Ericsson      A00001  A00001_Macro            PERAK
# 1         7  NORTHERN    Huawei      A00003  A00003_Macro            PERAK
# 2        16  NORTHERN    Huawei      A00004  A00004_Macro            PERAK
# 3        24  NORTHERN    Huawei      A00005  A00005_Macro            PERAK
# 4        29  NORTHERN    Huawei      A00006  A00006_Macro            PERAK
# ...     ...       ...       ...         ...           ...              ...
# 9380  56358  SOUTHERN    Huawei      Y00023  Y00023_Macro  NEGERI SEMBILAN
# 9381  56364  NORTHERN    Huawei      Y00029  Y00029_Macro            PERAK
# 9382  56367  NORTHERN    Huawei      Y00048  Y00048_Macro            PERAK
# 9383  56370  NORTHERN    Huawei      Y00054  Y00054_Macro            KEDAH
# 9384  56376   CENTRAL    Huawei      Y00056  Y00056_Macro         SELANGOR
#
# ...

# %%
df[['test3','test4']] = str(df.NC_NAME.str.split("_"))

# %%
df
# Out:
#          NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID            STATE  \
# 0         1   CENTRAL  Ericsson      A00001  A00001_Macro            PERAK
# 1         7  NORTHERN    Huawei      A00003  A00003_Macro            PERAK
# 2        16  NORTHERN    Huawei      A00004  A00004_Macro            PERAK
# 3        24  NORTHERN    Huawei      A00005  A00005_Macro            PERAK
# 4        29  NORTHERN    Huawei      A00006  A00006_Macro            PERAK
# ...     ...       ...       ...         ...           ...              ...
# 9380  56358  SOUTHERN    Huawei      Y00023  Y00023_Macro  NEGERI SEMBILAN
# 9381  56364  NORTHERN    Huawei      Y00029  Y00029_Macro            PERAK
# 9382  56367  NORTHERN    Huawei      Y00048  Y00048_Macro            PERAK
# 9383  56370  NORTHERN    Huawei      Y00054  Y00054_Macro            KEDAH
# 9384  56376   CENTRAL    Huawei      Y00056  Y00056_Macro         SELANGOR
#
# ...

# %%
df[['test1','test2']] = [aa,bb]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-d51089931840> in <module>
# ----> 1 df[['test1','test2']] = [aa,bb]
#
# NameError: name 'aa' is not defined

# %%
df.NC_NAME.apply(lambda x: pd.Series(str(x).split("_",1)))
# Out:
#            0                            1
# 0     A037B2              HUTAN MELINTANG
# 1     A045A3                        GERIK
# 2     A045A1               PENGKALAN HULU
# 3     A045A3                        GERIK
# 4     A036B4  HULU BERNAM TIMUR DAN BARAT
# ...      ...                          ...
# 9380  N071A3                      KUNDANG
# 9381  A037B1                CHANGKAT JONG
# 9382  A036B3  HULU BERNAM TIMUR DAN BARAT
# 9383  K004A5                        TAJAR
# 9384  B061F3                 SUNGAI BULOH
#
# [9385 rows x 2 columns]

# %% [markdown]
# ###split to str1 and str2 then insert to test3 and test4 columns(if doesnt exist, then create)

# %%
df[['test3','test4']] = df.NC_NAME.apply(lambda x: pd.Series(str(x).split("_",1))) ##successful, split to str1 and str2 then create to test3 and ets4 columns

# %%
df
# Out:
#          NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID            STATE  \
# 0         1   CENTRAL  Ericsson      A00001  A00001_Macro            PERAK
# 1         7  NORTHERN    Huawei      A00003  A00003_Macro            PERAK
# 2        16  NORTHERN    Huawei      A00004  A00004_Macro            PERAK
# 3        24  NORTHERN    Huawei      A00005  A00005_Macro            PERAK
# 4        29  NORTHERN    Huawei      A00006  A00006_Macro            PERAK
# ...     ...       ...       ...         ...           ...              ...
# 9380  56358  SOUTHERN    Huawei      Y00023  Y00023_Macro  NEGERI SEMBILAN
# 9381  56364  NORTHERN    Huawei      Y00029  Y00029_Macro            PERAK
# 9382  56367  NORTHERN    Huawei      Y00048  Y00048_Macro            PERAK
# 9383  56370  NORTHERN    Huawei      Y00054  Y00054_Macro            KEDAH
# 9384  56376   CENTRAL    Huawei      Y00056  Y00056_Macro         SELANGOR
#
# ...

# %%
df.drop(columns=['F','S'])
# Out:
#          NO    REGION    VENDOR LOCATION ID  ZOOM SITE ID            STATE  \
# 0         1   CENTRAL  Ericsson      A00001  A00001_Macro            PERAK
# 1         7  NORTHERN    Huawei      A00003  A00003_Macro            PERAK
# 2        16  NORTHERN    Huawei      A00004  A00004_Macro            PERAK
# 3        24  NORTHERN    Huawei      A00005  A00005_Macro            PERAK
# 4        29  NORTHERN    Huawei      A00006  A00006_Macro            PERAK
# ...     ...       ...       ...         ...           ...              ...
# 9380  56358  SOUTHERN    Huawei      Y00023  Y00023_Macro  NEGERI SEMBILAN
# 9381  56364  NORTHERN    Huawei      Y00029  Y00029_Macro            PERAK
# 9382  56367  NORTHERN    Huawei      Y00048  Y00048_Macro            PERAK
# 9383  56370  NORTHERN    Huawei      Y00054  Y00054_Macro            KEDAH
# 9384  56376   CENTRAL    Huawei      Y00056  Y00056_Macro         SELANGOR
#
# ...

# %%
a = df.NC_NAME.str.split("_",1)

# %%
a
# Out:
# 0                   [A037B2, HUTAN MELINTANG]
# 1                             [A045A3, GERIK]
# 2                    [A045A1, PENGKALAN HULU]
# 3                             [A045A3, GERIK]
# 4       [A036B4, HULU BERNAM TIMUR DAN BARAT]
#                         ...
# 9380                        [N071A3, KUNDANG]
# 9381                  [A037B1, CHANGKAT JONG]
# 9382    [A036B3, HULU BERNAM TIMUR DAN BARAT]
# 9383                          [K004A5, TAJAR]
# 9384                   [B061F3, SUNGAI BULOH]
# Name: NC_NAME, Length: 9385, dtype: object

# %%
a[0]
# Out:
# ['A037B2', 'HUTAN MELINTANG']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a[10]
# Out:
# ['A037B1', 'CHANGKAT JONG']

# %%
de = pd.DataFrame(a[10])

# %%
de
# Out:
#                0
# 0         A037B1
# 1  CHANGKAT JONG

# %%
de[['aa','bb']] = a[1] ## add value to columns, create if not exist.

# %%
de
# Out:
#                0      aa     bb
# 0         A037B1  A045A3  GERIK
# 1  CHANGKAT JONG  A045A3  GERIK

# %%
df['NC_NAME']
# Out:
# 0                   A037B2_HUTAN MELINTANG
# 1                             A045A3_GERIK
# 2                    A045A1_PENGKALAN HULU
# 3                             A045A3_GERIK
# 4       A036B4_HULU BERNAM TIMUR DAN BARAT
#                        ...
# 9380                        N071A3_KUNDANG
# 9381                  A037B1_CHANGKAT JONG
# 9382    A036B3_HULU BERNAM TIMUR DAN BARAT
# 9383                          K004A5_TAJAR
# 9384                   B061F3_SUNGAI BULOH
# Name: NC_NAME, Length: 9385, dtype: object

# %%
df[['NC_NAME','test3','test4']] ## display columns
# Out:
#                                  NC_NAME   test3                        test4
# 0                 A037B2_HUTAN MELINTANG  A037B2              HUTAN MELINTANG
# 1                           A045A3_GERIK  A045A3                        GERIK
# 2                  A045A1_PENGKALAN HULU  A045A1               PENGKALAN HULU
# 3                           A045A3_GERIK  A045A3                        GERIK
# 4     A036B4_HULU BERNAM TIMUR DAN BARAT  A036B4  HULU BERNAM TIMUR DAN BARAT
# ...                                  ...     ...                          ...
# 9380                      N071A3_KUNDANG  N071A3                      KUNDANG
# 9381                A037B1_CHANGKAT JONG  A037B1                CHANGKAT JONG
# 9382  A036B3_HULU BERNAM TIMUR DAN BARAT  A036B3  HULU BERNAM TIMUR DAN BARAT
# 9383                        K004A5_TAJAR  K004A5                        TAJAR
# 9384                 B061F3_SUNGAI BULOH  B061F3                 SUNGAI BULOH
#
# [9385 rows x 3 columns]

# %%
df.loc[0,['NC_NAME','test3','test4']] ## display selected row with selected column
# Out:
# NC_NAME    A037B2_HUTAN MELINTANG
# test3                      A037B2
# test4             HUTAN MELINTANG
# Name: 0, dtype: object

# %%
df.sum()
# Out:
# NO                                                         272441590
# REGION             CENTRALNORTHERNNORTHERNNORTHERNNORTHERNNORTHER...
# VENDOR             EricssonHuaweiHuaweiHuaweiHuaweiHuaweiHuaweiHu...
# LOCATION ID        A00001A00003A00004A00005A00006A00008A00009A000...
# ZOOM SITE ID       A00001_MacroA00003_MacroA00004_MacroA00005_Mac...
# STATE              PERAKPERAKPERAKPERAKPERAKPERAKPERAKPERAKPERAKP...
# SALES REGION       NORTHERNNORTHERNNORTHERNNORTHERNNORTHERNNORTHE...
# TERRITORY CODE     A037BA045AA045AA045AA036BA042AA041AA039BA037BA...
# SALES TERRITORY    HILIR PERAK_BGN DATOHULU PERAKULU PERAKULU PER...
# SALES TIER         Tier 2Tier 2Tier 2Tier 2Tier 2Tier 2Tier 2Tier...
# NC_CODE            A037B2A045A3A045A1A045A3A036B4A042A2A041A3A039...
# NC_NAME            A037B2_HUTAN MELINTANGA045A3_GERIKA045A1_PENGK...
# PROJECT SITE ID    CL50630NL40212NL40590NL40216NL40151NL40737NL40...
# SITENAME           A037B_A00001OD_KGTLKBULOHA045A_A00003OD_TMGRIK...
# ...

# %%
df.sum(LONGITUDE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-d0a8d954b769> in <module>
# ----> 1 df.sum(LONGITUDE)
#
# NameError: name 'LONGITUDE' is not defined

# %% [markdown]
# @@direct operation to the column...

# %%
df['LONGITUDE'].sum()
# Out:
# 980724.949795792

# %%
df['LONGITUDE'].mode()
# Out:
# 0    101.7936
# dtype: float64

# %%
df['LONGITUDE'].median()
# Out:
# 102.22382

# %%
df['LONGITUDE'].cumsum()
# Out:
# 0          100.981370
# 1          202.109532
# 2          303.108471
# 3          404.315052
# 4          505.846055
#             ...
# 9380    980320.275337
# 9381    980421.474287
# 9382    980522.995187
# 9383    980623.363981
# 9384    980724.949796
# Name: LONGITUDE, Length: 9385, dtype: float64

# %%
df['LONGITUDE'].mad()
# Out:
# 3.990749921502754

# %%
plt.plot(df['LONGITUDE'], df['LATITUDE'])
plt.xlabel('x - LONGITUDE')
plt.ylabel('y - LATITUDE')
# Out:
# Text(0, 0.5, 'y - LATITUDE')

# %%
plt.plot(df['LONGITUDE'])

# %%
plt.plot(df['LATITUDE'])

# %%
plt.plot(df['LATITUDE'], df['LONGITUDE'])
plt.xlabel('x - LATITUDE')
plt.ylabel('y - LONGITUDE')
# Out:
# Text(0, 0.5, 'y - LONGITUDE')

# %%
plt.scatter(df['LONGITUDE'], df['LATITUDE'], label= "stars", color= "green", 
            marker= "*", s=30)
#plt.plot(df['LONGITUDE'], df['LATITUDE'])
plt.xlabel('x - LONGITUDE')
plt.ylabel('y - LATITUDE')
# Out:
# Text(0, 0.5, 'y - LATITUDE')

# %%
pd.DataFrame(df.NC_NAME.str.split("_",1))
# Out:
#                                     NC_NAME
# 0                 [A037B2, HUTAN MELINTANG]
# 1                           [A045A3, GERIK]
# 2                  [A045A1, PENGKALAN HULU]
# 3                           [A045A3, GERIK]
# 4     [A036B4, HULU BERNAM TIMUR DAN BARAT]
# ...                                     ...
# 9380                      [N071A3, KUNDANG]
# 9381                [A037B1, CHANGKAT JONG]
# 9382  [A036B3, HULU BERNAM TIMUR DAN BARAT]
# 9383                        [K004A5, TAJAR]
# 9384                 [B061F3, SUNGAI BULOH]
#
# [9385 rows x 1 columns]

# %%
df[['F','S']] = df['NC_NAME'].str.split("_",1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-657a1a206c1c> in <module>
# ----> 1 df[['F','S']] = df['NC_NAME'].str.split("_",1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3158             self._setitem_frame(key, value)
#    3159         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3160             self._setitem_array(key, value)
#    3161         else:
#    3162             # set column
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3196                 )[1]
#    3197                 self._check_setitem_copy()
# -> 3198                 self.iloc[:, indexer] = value
#    3199
#    3200     def _setitem_frame(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
# ...

# %%
df['NC_NAME'].str.split("_",1)
# Out:
# 0                   [A037B2, HUTAN MELINTANG]
# 1                             [A045A3, GERIK]
# 2                    [A045A1, PENGKALAN HULU]
# 3                             [A045A3, GERIK]
# 4       [A036B4, HULU BERNAM TIMUR DAN BARAT]
#                         ...
# 9380                        [N071A3, KUNDANG]
# 9381                  [A037B1, CHANGKAT JONG]
# 9382    [A036B3, HULU BERNAM TIMUR DAN BARAT]
# 9383                          [K004A5, TAJAR]
# 9384                   [B061F3, SUNGAI BULOH]
# Name: NC_NAME, Length: 9385, dtype: object

# %% [markdown]
# @to run function to split the df.NC_NAME and put into dataframe format, good to assing value to another dataframe

# %%
df.NC_NAME.apply(lambda x: pd.Series(str(x).split("_",1)))
# Out:
#            0                            1
# 0     A037B2              HUTAN MELINTANG
# 1     A045A3                        GERIK
# 2     A045A1               PENGKALAN HULU
# 3     A045A3                        GERIK
# 4     A036B4  HULU BERNAM TIMUR DAN BARAT
# ...      ...                          ...
# 9380  N071A3                      KUNDANG
# 9381  A037B1                CHANGKAT JONG
# 9382  A036B3  HULU BERNAM TIMUR DAN BARAT
# 9383  K004A5                        TAJAR
# 9384  B061F3                 SUNGAI BULOH
#
# [9385 rows x 2 columns]

# %%
a = df['NC_NAME'].str.split("_",1)

# %%
a
# Out:
# 0                   [A037B2, HUTAN MELINTANG]
# 1                             [A045A3, GERIK]
# 2                    [A045A1, PENGKALAN HULU]
# 3                             [A045A3, GERIK]
# 4       [A036B4, HULU BERNAM TIMUR DAN BARAT]
#                         ...
# 9380                        [N071A3, KUNDANG]
# 9381                  [A037B1, CHANGKAT JONG]
# 9382    [A036B3, HULU BERNAM TIMUR DAN BARAT]
# 9383                          [K004A5, TAJAR]
# 9384                   [B061F3, SUNGAI BULOH]
# Name: NC_NAME, Length: 9385, dtype: object

# %%
a[0][0]
# Out:
# 'A037B2'

# %%
a[0][1]
# Out:
# 'HUTAN MELINTANG'

# %%
type(df.NC_NAME.apply(lambda x: pd.Series(str(x).split("_",1))))
# Out:
# pandas.core.frame.DataFrame

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df.loc[df['LATITUDE'] > 6, ['STATE', 'TERRITORY CODE']]
# Out:
#          STATE TERRITORY CODE
# 3052  KELANTAN          D020B
# 3053  KELANTAN          D020B
# 3056  KELANTAN          D017C
# 3058  KELANTAN          D017C
# 3059  KELANTAN          D017B
# ...        ...            ...
# 8220     SABAH          S109A
# 8228     SABAH          S093B
# 8233     SABAH          S109A
# 9372     SABAH          S093C
# 9383     KEDAH          K004A
#
# [777 rows x 2 columns]

# %%
df3 = df.loc[df['LATITUDE'] > 6, ['STATE', 'TERRITORY CODE']]

# %% [markdown]
# #to get the unique value from the result

# %%
df3.STATE.unique()
# Out:
# array(['KELANTAN', 'KEDAH', 'PERLIS', 'SABAH', 'Sabah'], dtype=object)

# %%
df3 = df.loc[df['LATITUDE'] > 6, ['STATE', 'TERRITORY CODE']].STATE.unique()

# %%
df3
# Out:
# array(['KELANTAN', 'KEDAH', 'PERLIS', 'SABAH', 'Sabah'], dtype=object)

# %% [markdown]
# ###To sort the dataframe with value , in this case column LATITUDE, descending order

# %%
rslt_df = df.sort_values(by = 'LATITUDE', ascending = False)

# %%
rslt_df
# Out:
#          NO   REGION    VENDOR LOCATION ID  ZOOM SITE ID    STATE  \
# 7924  47507    SABAH  Ericsson      S00948  S00948_Macro    SABAH
# 7923  47504    SABAH  Ericsson      S00944  S00944_Macro    SABAH
# 7771  46862    SABAH  Ericsson      S00576  S00576_Macro    SABAH
# 8049  48039    SABAH  Ericsson      S01317  S01317_Macro    SABAH
# 7857  47233    SABAH  Ericsson      S00776  S00776_Macro    SABAH
# ...     ...      ...       ...         ...           ...      ...
# 6611  41499  SARAWAK  Ericsson      Q00574  Q00574_Macro  SARAWAK
# 6848  42609  SARAWAK  Ericsson      Q01007  Q01007_Macro  SARAWAK
# 6851  42619  SARAWAK  Ericsson      Q01010  Q01010_Macro  SARAWAK
# 6653  41703  SARAWAK  Ericsson      Q00642  Q00642_Macro  SARAWAK
# 6850  42615  SARAWAK  Ericsson      Q01009  Q01009_Macro  SARAWAK
#
#      SALES REGION TERRITORY CODE SALES TERRITORY SALES TIER  ... First Second  \
# 7924        SABAH          S096A           KUDAT     Tier 2  ...   NaN    NaN
# ...
